# %% [markdown]
# # JET Global Sensitivity Analysis with SALib (Sobol Indices)
#
# This notebook performs a Global Sensitivity Analysis (GSA) of the JET ensemble using ECOSTRESS Collection 2 Cal-Val data and **Sobol indices** via the `SALib` package. It computes first-order ($S_1$) and total-order ($S_T$) indices to rigorously quantify the fractional variance each input variable contributes to model outputs like latent heat flux and evapotranspiration.[cite: 1]

# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname("__file__"), '..')))
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import SALib modules for Global Sensitivity Analysis
from SALib.sample import saltelli
from SALib.analyze import sobol
from sklearn.metrics import r2_score, mean_squared_error

# Custom JET modules
from JET3 import process_JET_table, load_ECOv002_calval_JET_inputs

# %% [markdown]
# ## Configuration and Problem Setup
# Load the baseline data and dynamically define the physical boundaries based on the absolute minimum and maximum values of the dataset.

# %%
input_variables = [
    "ST_C", "NDVI", "albedo", "Ta_C", "RH", 
    "AOT", "COT", "vapor_gccm", "ozone_cm", 
    "elevation_m", "canopy_height_meters"
]

output_variables = [
    "Rn_Wm2", "ET_daylight_kg"
]

# Load baseline data first
input_df = load_ECOv002_calval_JET_inputs()

# Drop missing values from required inputs
input_df = input_df.dropna(subset=[var for var in input_variables if var in input_df.columns])

# Set bounds using the absolute minimum and maximum of the real data (no filtering applied)
input_min = {var: input_df[var].min() for var in input_variables if var in input_df.columns}
input_max = {var: input_df[var].max() for var in input_variables if var in input_df.columns}

print(f"Total valid rows without filtering: {len(input_df)}")
# Out:
# Total valid rows without filtering: 1061

# %% [markdown]
# ## Analyze Baseline Data In-Situ Accuracy[cite: 1]

# %%
def plot_insitu_accuracy(df, variable_name, color=None, model_name=None, cmap="jet"):
    """
    Generates a scatter plot comparing a single in-situ variable to its model equivalent.
    """
    try:
        insitu_variable = f"insitu_{variable_name}"
        model_prefix = f"{model_name} " if model_name else ""
        print(f"Analyzing {model_prefix}accuracy for {variable_name} compared to {insitu_variable}")
        
        x_variable = insitu_variable
        y_variable = variable_name

        # Check if required columns exist
        required_cols = [x_variable, y_variable, 'ST_C']
        missing_cols = [col for col in required_cols if col not in df.columns]
        if missing_cols:
            raise KeyError(f"Missing required columns in dataframe: {missing_cols}")

        # Filter out rows with NaN values in relevant variables
        valid_data = df[required_cols].dropna()
        
        if valid_data.empty:
            print(f"No valid data remaining after dropping NaNs for {variable_name}. Skipping.")
            return

        # Initialize figure
        plt.figure(figsize=(8, 6))
        
        sc = plt.scatter(
            x=valid_data[x_variable],
            y=valid_data[y_variable],
            c=valid_data[color] if color is not None else None,
            cmap=cmap,
            s=5
        )

        # Calculate OLS regression line coefficients
        coefs = np.polyfit(valid_data[x_variable], valid_data[y_variable], 1)

        # Add 1-to-1 line across the entire axis
        plt.axline((0, 0), slope=1, color='black', linestyle='-', linewidth=1, label='1:1 Line')

        # Add OLS regression line across the entire axis
        plt.axline((0, coefs[1]), slope=coefs[0], color='black', linestyle='--', linewidth=1, label='OLS Fit')

        # Calculate R-squared and RMSE
        y_true = valid_data[y_variable]
        y_pred = coefs[0] * valid_data[x_variable] + coefs[1]
        r2 = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))

        # Annotate R-squared and RMSE on plot in lower left corner
        plt.annotate(f"$R^2$ = {r2:.2f}\nRMSE = {rmse:.1f}",
                    xy=(0.05, 0.05), xycoords='axes fraction',
                    ha='left', va='bottom',
                    fontsize=10,
                    bbox=dict(boxstyle='round', fc='white', ec='gray', alpha=0.7))

        # Formatting
        plt.grid(True, zorder=0) 
        plt.xlabel(f"In-Situ {variable_name}")
        plt.ylabel(f"{model_prefix}{variable_name}")
        plt.title(f"Accuracy Comparison\nof In-Situ {variable_name}\nto {model_prefix}{variable_name}")
        plt.colorbar(sc, label="ECOSTRESS Surface Temperature (°C)")
        plt.legend(loc='upper right')
        plt.show()
        plt.close() # Free memory after displaying
        
    except Exception as e:
        print(f"Error processing {insitu_variable}: {e}")

plot_insitu_accuracy(input_df, variable_name="Ta_C", color="ST_C")
# Out:
# Analyzing accuracy for Ta_C compared to insitu_Ta_C

# %% [markdown]
# ## Generate Saltelli Samples
# Construct the problem dictionary and utilize Saltelli's extension of the Sobol sequence to generate parameter values.[cite: 1]

# %%
problem = {
    'num_vars': len(input_variables),
    'names': input_variables,
    'bounds': [[input_min[var], input_max[var]] for var in input_variables]
}

# Generate Saltelli samples. Total iterations = N * (2D + 2)
# With D=11 and N=256, total model evaluations will be 6,144.
N = 256 
param_values = saltelli.sample(problem, N, calc_second_order=True)
# Out:
# /var/folders/bv/410kt7f93x78j9dww00h1pz80000gn/T/ipykernel_65254/65101988.py:10: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5.1 Please use `salib.sample.sobol`
#   param_values = saltelli.sample(problem, N, calc_second_order=True)

# %% [markdown]
# ## Process Samples via the JET Model
# We broadcast a static base row from the dataframe to match the Saltelli matrix size, overwrite our input variables with the generated samples, and execute the forward run.[cite: 1]

# %%
# Construct a sampled DataFrame by repeating a base row
base_row = input_df.iloc[0:1]
sampled_df = pd.concat([base_row] * param_values.shape[0], ignore_index=True)

# Inject the perturbed Sobol variables into the DataFrame
sampled_df[input_variables] = param_values
print(f"Executing {param_values.shape[0]} runs for Global Sensitivity Analysis...")

# Run the forward process
processed_samples = process_JET_table(sampled_df)
# Out:
# Executing 6144 runs for Global Sensitivity Analysis...
# [2026-08-07 17:50:08 INFO] starting JET table processing
# [2026-08-07 17:50:08 INFO] started extracting geometry from JET input table
# [2026-08-07 17:50:08 INFO] completed extracting geometry from JET input table (0.038 seconds)
# [2026-08-07 17:50:08 INFO] started extracting time from JET input table
# [2026-08-07 17:50:08 INFO] completed extracting time from JET input table (0.003 seconds)
# [2026-08-07 17:50:08 INFO] running Forest Light Environmental Simulator
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 235us/step
# [2026-08-07 17:50:08 INFO] completed processing FLiES-ANN in 0.37 seconds
# [2026-08-07 17:50:08 INFO] variable PAR_albedo (float64) with [0.09390986] unique values
# [2026-08-07 17:50:08 INFO] * 0.0939098562443398: 6144
# [2026-08-07 17:50:08 INFO] variable NIR_albedo (float64) with [0.35587504] unique values
# [2026-08-07 17:50:08 INFO] * 0.3558750381101216: 6144
# [2026-08-07 17:50:08 INFO] variable PAR_direct_Wm2 min: 2.934 mean: 26.668 max: 263.589 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable SWin_FLiES_ANN min: 65.389 mean: 263.056 max: 750.835 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] running Breathing Earth System Simulator
# <class 'numpy.ndarray'>
# float32
# [2026-08-07 17:50:08 INFO] variable SZA_deg (float32) with [48.498672] unique values
# [2026-08-07 17:50:08 INFO] * 48.498672: 6144
# [2026-08-07 17:50:08 INFO] variable CI (float64) with [0.28235294] unique values
# [2026-08-07 17:50:08 INFO] * 0.2823529411764706: 6144
# [2026-08-07 17:50:08 INFO] variable elevation_m min: 7.842 mean: 1752.500 max: 3497.158 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable NDVI_minimum (float64) with [0.40873316] unique values
# [2026-08-07 17:50:08 INFO] * 0.4087331578417219: 6144
# [2026-08-07 17:50:08 INFO] variable NDVI_maximum (float64) with [0.8556929] unique values
# [2026-08-07 17:50:08 INFO] * 0.8556928956658199: 6144
# [2026-08-07 17:50:08 INFO] variable C4_fraction (float64) with [0.07753171] unique values
# [2026-08-07 17:50:08 INFO] * 0.0775317136278871: 6144
# [2026-08-07 17:50:08 INFO] variable carbon_uptake_efficiency (float64) with [0.08] unique values
# [2026-08-07 17:50:08 INFO] * 0.0799999982118606: 6144
# [2026-08-07 17:50:08 INFO] variable kn (float64) with [0.41] unique values
# [2026-08-07 17:50:08 INFO] * 0.4099999964237213: 6144
# [2026-08-07 17:50:08 INFO] variable peakVCmax_C3_μmolm2s1 (float64) with [87.34543335] unique values
# [2026-08-07 17:50:08 INFO] * 87.34543334528844: 6144
# [2026-08-07 17:50:08 INFO] variable peakVCmax_C4_μmolm2s1 (float64) with [51.04062441] unique values
# [2026-08-07 17:50:08 INFO] * 51.04062440664798: 6144
# [2026-08-07 17:50:08 INFO] variable ball_berry_slope_C3 (float64) with [9.5] unique values
# [2026-08-07 17:50:08 INFO] * 9.5: 6144
# [2026-08-07 17:50:08 INFO] variable ball_berry_slope_C4 (float64) with [4.9519627] unique values
# [2026-08-07 17:50:08 INFO] * 4.951962701536608: 6144
# [2026-08-07 17:50:08 INFO] variable ball_berry_intercept_C3 (float64) with [0.00526687] unique values
# [2026-08-07 17:50:08 INFO] * 0.0052668737343494: 6144
# [2026-08-07 17:50:08 INFO] variable KG_climate (float32) with [3.] unique values
# [2026-08-07 17:50:08 INFO] * 3.0: 6144
# [2026-08-07 17:50:08 INFO] variable canopy_height_meters min: 0.059 mean: 15.096 max: 30.133 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] All GEOS-5 FP inputs provided, no retrieval needed.
# [2026-08-07 17:50:08 INFO] variable canopy_temperature_C min: -14.234 mean: 35.840 max: 85.914 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable soil_temperature_C min: -14.234 mean: 35.840 max: 85.914 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] using given FLiES output as BESS parameters
# [2026-08-07 17:50:08 INFO] variable Ps_Pa min: 62986.012 mean: 82296.182 max: 101232.443 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable VPD_Pa min: 5.199 mean: 812.458 max: 4859.613 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable RH min: 0.274 mean: 0.628 max: 0.982 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable desTa min: 16.377 mean: 130.013 max: 385.780 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable ddesTa min: 1.205 mean: 6.838 max: 17.833 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable gamma min: 40.656 mean: 54.299 max: 68.312 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable Cp min: 1005.450 mean: 1014.339 max: 1058.977 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable rhoa min: 0.762 mean: 1.006 max: 1.348 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable epsa min: 0.671 mean: 0.910 max: 0.999 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable R min: 21.065 mean: 41.899 max: 110.557 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable Rc min: 21.065 mean: 41.899 max: 110.557 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable Rs min: 10.532 mean: 20.949 max: 55.278 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable SFd (float64) with [0.05905949] unique values
# [2026-08-07 17:50:08 INFO] * 0.05905948789791865: 6144
# [2026-08-07 17:50:08 INFO] variable SFd2 (float64) with [0.24941134] unique values
# [2026-08-07 17:50:08 INFO] * 0.2494113382413926: 6144
# [2026-08-07 17:50:08 INFO] variable DL (float64) with [10.04591982] unique values
# [2026-08-07 17:50:08 INFO] * 10.045919816401328: 6144
# [2026-08-07 17:50:08 INFO] variable Ra (float64) with [884.32062362] unique values
# [2026-08-07 17:50:08 INFO] * 884.3206236236358: 6144
# [2026-08-07 17:50:08 INFO] variable fStress min: 0.003 mean: 0.705 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable VCmax_C3_sunlit_μmolm2s1 min: 0.469 mean: 35.225 max: 100.906 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable VCmax_C4_sunlit_μmolm2s1 min: 0.274 mean: 20.584 max: 58.965 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable VCmax_C3_shaded_μmolm2s1 min: 0.004 mean: 39.768 max: 220.142 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable VCmax_C4_shaded_μmolm2s1 min: 0.002 mean: 23.238 max: 128.641 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable PARDiff min: 31.100 mean: 99.124 max: 172.490 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable PARDir min: 2.934 mean: 26.668 max: 263.589 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable NIRDiff min: 25.406 mean: 116.438 max: 291.646 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable NIRDir min: 0.000 mean: 3.663 max: 273.826 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable UV min: 4.663 mean: 16.934 max: 47.008 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable SZA (float32) with [48.498672] unique values
# [2026-08-07 17:50:08 INFO] * 48.498672: 6144
# [2026-08-07 17:50:08 INFO] variable LAI min: 0.022 mean: 1.488 max: 4.480 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable CI (float64) with [0.28235294] unique values
# [2026-08-07 17:50:08 INFO] * 0.2823529411764706: 6144
# [2026-08-07 17:50:08 INFO] variable albedo_visible (float64) with [0.09390986] unique values
# [2026-08-07 17:50:08 INFO] * 0.0939098562443398: 6144
# [2026-08-07 17:50:08 INFO] variable albedo_NIR (float64) with [0.35587504] unique values
# [2026-08-07 17:50:08 INFO] * 0.3558750381101216: 6144
# [2026-08-07 17:50:08 INFO] variable kb (float32) with [0.75456053] unique values
# [2026-08-07 17:50:08 INFO] * 0.75456053: 6144
# [2026-08-07 17:50:08 INFO] variable kk_Pb (float32) with [0.6941957] unique values
# [2026-08-07 17:50:08 INFO] * 0.6941957: 6144
# [2026-08-07 17:50:08 INFO] variable kk_Nb (float64) with [0.31565532] unique values
# [2026-08-07 17:50:08 INFO] * 0.31565531660336676: 6144
# [2026-08-07 17:50:08 INFO] variable kk_Nd (float64) with [0.1464155] unique values
# [2026-08-07 17:50:08 INFO] * 0.14641550464346323: 1
# [2026-08-07 17:50:08 INFO] variable fSun min: 0.182 mean: 0.244 max: 0.282 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable L_CI min: 0.006 mean: 0.420 max: 1.265 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable exp_kk_Pd_L_CI min: 0.402 mean: 0.758 max: 0.996 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable exp_kk_Nd_L_CI min: 0.831 mean: 0.941 max: 0.999 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APARin_Wm2 min: 0.203 mean: 27.414 max: 145.028 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APARin_sunlit_Wm2 min: 0.017 mean: 5.677 max: 98.347 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APARin_diffuse_Wm2 min: 0.186 mean: 17.641 max: 58.986 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APARin_scattered_sunlit_Wm2 min: 0.000 mean: 0.119 max: 2.516 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APARin_sunlit_Wm2 min: 0.203 mean: 23.438 max: 130.755 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APARin_shade_Wm2 min: 0.000 mean: 3.977 max: 24.861 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable PARin_soil_Wm2 min: 16.539 mean: 86.142 max: 268.408 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APAR_Soil min: 14.058 mean: 73.221 max: 228.147 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APARout_sunlit_Wm2 min: 1.012 mean: 10.228 max: 38.607 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APARout_shade_Wm2 min: 0.030 mean: 2.693 max: 10.160 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APAR_sunlit_Wm2 min: 5.455 mean: 33.666 max: 139.078 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APAR_shade_Wm2 min: 0.031 mean: 6.670 max: 32.315 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable ANIRin_sunlit_Wm2 min: 0.027 mean: 3.803 max: 36.241 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable ANIRin_shade_Wm2 min: 0.000 mean: 0.923 max: 9.945 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable NIRin_soil_Wm2 min: 15.630 mean: 72.355 max: 236.778 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable ANIR_soil_Wm2 min: 10.941 mean: 50.648 max: 165.744 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable ANIRout_sunlit_Wm2 min: 4.262 mean: 20.471 max: 69.538 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable ANIRout_Wm2 min: 0.008 mean: 1.236 max: 7.446 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable ANIR_sunlit_Wm2 min: 4.987 mean: 24.274 max: 85.698 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable ANIR_shade_Wm2 min: 0.008 mean: 2.159 max: 17.391 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable G_Wm2 min: 3.936 mean: 20.502 max: 63.881 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable ASW_sunlit_Wm2 min: 10.871 mean: 59.304 max: 215.273 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable ASW_shade_Wm2 min: 0.078 mean: 13.496 max: 64.320 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable ASW_soil_Wm2 min: 26.825 mean: 133.873 max: 433.019 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APAR_sunlit_Wm2 min: 5.455 mean: 33.666 max: 139.078 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APAR_sunlit_μmolm2s1 min: 24.875 mean: 153.515 max: 634.194 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APAR_shade_Wm2 min: 0.031 mean: 6.670 max: 32.315 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APAR_shade_μmolm2s1 min: 0.141 mean: 30.416 max: 147.357 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable fSun min: 0.182 mean: 0.244 max: 0.282 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APAR_sunlit_μmolm2s1 min: 24.875 mean: 153.515 max: 634.194 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable APAR_shade_μmolm2s1 min: 0.141 mean: 30.416 max: 147.357 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable ASW_sunlit_Wm2 min: 10.871 mean: 59.304 max: 215.273 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable ASW_shade_Wm2 min: 0.078 mean: 13.496 max: 64.320 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable ASW_soil_Wm2 min: 26.825 mean: 133.873 max: 433.019 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable G_Wm2 min: 3.936 mean: 20.502 max: 63.881 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable GPP_C3 min: 0.000 mean: 2.477 max: 22.146 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable LE_C3 min: 0.000 mean: 46.450 max: 920.941 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable LE_soil_C3 min: 0.000 mean: 29.884 max: 595.817 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable LE_canopy_C3 min: 0.000 mean: 16.565 max: 474.363 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable Rn_C3 min: 0.000 mean: 159.741 max: 1000.000 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable Rn_soil_C3 min: 0.000 mean: 82.918 max: 791.396 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable Rn_canopy_C3 min: 0.000 mean: 83.603 max: 1007.482 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable GPP_C4 min: 0.000 mean: 2.398 max: 37.840 nan: 8.59% (nan)
# [2026-08-07 17:50:08 INFO] variable LE_C4 min: 0.000 mean: 46.029 max: 969.405 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable LE_soil_C4 min: 0.000 mean: 29.884 max: 595.817 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable LE_canopy_C4 min: 0.000 mean: 16.144 max: 468.541 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable Rn_C4 min: 0.000 mean: 159.741 max: 1000.000 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable Rn_soil_C4 min: 0.000 mean: 82.918 max: 791.396 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] variable Rn_canopy_C4 min: 0.000 mean: 83.603 max: 1007.482 nan: 0.00% (nan)
# [2026-08-07 17:50:08 INFO] started daylight ET upscaling
# [2026-08-07 17:50:09 INFO] completed daylight ET upscaling (elapsed: 0.08 seconds)
# [2026-08-07 17:50:09 INFO] completed processing BESS-JPL in 0.27 seconds
# [2026-08-07 17:50:09 INFO] variable Rn_BESS_Wm2 min: 0.000 mean: 159.741 max: 1000.000 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable Rn_BESS_Wm2 min: 0.000 mean: 159.741 max: 1000.000 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_BESS_Wm2 min: 0.000 mean: 46.417 max: 921.476 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] calculating solar day of year
# [2026-08-07 17:50:09 INFO] calculating solar hour of day
# [2026-08-07 17:50:09 INFO] calculating daylight hours and sunrise hour
# [2026-08-07 17:50:09 INFO] variable LE_BESS_Wm2 min: 0.000 mean: 46.417 max: 921.476 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable GPP_inst_umol_m2_s min: 0.000 mean: 2.471 max: 22.553 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] starting Verma net radiation processing
# [2026-08-07 17:50:09 INFO] variable SWout_Wm2 min: 1.953 mean: 88.450 max: 418.367 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable SWnet_Wm2 min: 50.240 mean: 174.606 max: 636.421 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable LWin_Wm2 min: 173.475 mean: 306.324 max: 518.258 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable LWout_Wm2 min: 241.578 mean: 516.009 max: 893.522 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable Rn_Wm2 min: 0.000 mean: 75.972 max: 803.032 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] Verma net radiation processing complete in 0.00 seconds
# [2026-08-07 17:50:09 INFO] running Surface Temperature Initiated Closure
# [2026-08-07 17:50:09 INFO] variable Ms min: 0.000 mean: 0.248 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] running STIC iteration 1 / 3
# [2026-08-07 17:50:09 INFO] using variable Priestley-Taylor alpha with mean: 0.933
# [2026-08-07 17:50:09 INFO] completed STIC iteration 1 / 3 with max LE change: 1713.033 (0.00153945799684152 seconds)
# [2026-08-07 17:50:09 INFO] variable SM_1 min: 0.000 mean: 0.261 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable G_1 min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_1 min: 0.000 mean: 40.317 max: 542.023 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] running STIC iteration 2 / 3
# [2026-08-07 17:50:09 INFO] using variable Priestley-Taylor alpha with mean: 1.418
# [2026-08-07 17:50:09 INFO] completed STIC iteration 2 / 3 with max LE change: 54.495 (0.004575541999656707 seconds)
# [2026-08-07 17:50:09 INFO] variable SM_2 min: 0.000 mean: 0.264 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable G_2 min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_2 min: 0.000 mean: 40.671 max: 542.023 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] running STIC iteration 3 / 3
# [2026-08-07 17:50:09 INFO] using variable Priestley-Taylor alpha with mean: 2.915
# [2026-08-07 17:50:09 INFO] completed STIC iteration 3 / 3 with max LE change: 184.912 (0.007761541986837983 seconds)
# [2026-08-07 17:50:09 INFO] variable SM_3 min: 0.000 mean: 0.264 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable G_3 min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_3 min: 0.000 mean: 43.095 max: 674.432 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] started daily ET upscaling (STIC-JPL)
# [2026-08-07 17:50:09 INFO] completed daily ET upscaling (elapsed: 0.08 seconds)
# [2026-08-07 17:50:09 INFO] completed processing STIC-JPL in 0.19 seconds
# [2026-08-07 17:50:09 INFO] variable LE_STIC_Wm2 min: 0.000 mean: 43.095 max: 674.432 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable ET_daylight_STIC_kg min: 0.000 mean: 0.465 max: 6.924 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_canoy_STIC_Wm2 min: 0.000 mean: 9.123 max: 395.749 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable G_STIC_Wm2 min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_canopy_fraction_STIC min: 0.000 mean: 0.172 max: 1.000 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] running Priestley-Taylor JPL with Soil Moisture
# [2026-08-07 17:50:09 INFO] starting PT-JPL-SM model run
# [2026-08-07 17:50:09 INFO] using given optimum temperature (Topt_C)
# [2026-08-07 17:50:09 INFO] variable Topt_C (float64) with [10.09] unique values
# [2026-08-07 17:50:09 INFO] * 10.09: 6144
# [2026-08-07 17:50:09 INFO] variable fAPARmax (float64) with [0.4659] unique values
# [2026-08-07 17:50:09 INFO] * 0.4659: 6144
# [2026-08-07 17:50:09 INFO] using given air temperature (Ta_C)
# [2026-08-07 17:50:09 INFO] variable Ta_C min: -14.499 mean: 12.553 max: 39.604 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] using given relative humidity (RH)
# [2026-08-07 17:50:09 INFO] variable RH min: 0.274 mean: 0.628 max: 0.982 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] using given soil moisture (SM)
# [2026-08-07 17:50:09 INFO] variable soil_moisture (float64) with [0.19235913] unique values
# [2026-08-07 17:50:09 INFO] * 0.19235913: 6144
# [2026-08-07 17:50:09 INFO] using given field capacity
# [2026-08-07 17:50:09 INFO] variable field_capacity (float64) with [0.24] unique values
# [2026-08-07 17:50:09 INFO] * 0.24: 6144
# [2026-08-07 17:50:09 INFO] using given wilting point
# [2026-08-07 17:50:09 INFO] variable wilting_point (float64) with [0.11] unique values
# [2026-08-07 17:50:09 INFO] * 0.11: 6144
# [2026-08-07 17:50:09 INFO] using given canopy height
# [2026-08-07 17:50:09 INFO] variable canopy_height_meters min: 0.059 mean: 15.096 max: 30.133 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] using given net radiation (Rn_Wm2) for PT-JPL-SM processing
# [2026-08-07 17:50:09 INFO] variable Rn_Wm2 min: 0.000 mean: 75.972 max: 803.032 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] using given soil heat flux (G_Wm2)
# [2026-08-07 17:50:09 INFO] variable G min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable fwet min: 0.006 mean: 0.259 max: 0.931 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable fREW (float64) with [1.] unique values
# [2026-08-07 17:50:09 INFO] * 1.0: 6144
# [2026-08-07 17:50:09 INFO] variable Topt_C (float64) with [10.09] unique values
# [2026-08-07 17:50:09 INFO] * 10.09: 6144
# [2026-08-07 17:50:09 INFO] variable Topt_C min: 10.090 mean: 18.167 max: 39.604 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable epsilon min: 0.199 mean: 0.565 max: 0.853 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable Rn_soil_Wm2 min: 0.000 mean: 38.214 max: 589.714 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_soil_Wm2 min: 0.000 mean: 29.337 max: 599.242 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable Rn_canopy_Wm2 min: 0.000 mean: 38.612 max: 511.241 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable PET min: 0.000 mean: 62.503 max: 816.006 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable fTRM min: 0.001 mean: 0.619 max: 1.000 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 19.242 max: 342.070 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_interception_Wm2 min: 0.000 mean: 9.002 max: 400.929 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_Wm2 min: 0.000 mean: 57.581 max: 789.186 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] started daylight ET upscaling
# [2026-08-07 17:50:09 INFO] completed daylight ET upscaling (elapsed: 0.12 seconds)
# [2026-08-07 17:50:09 INFO] PT-JPL-SM model run complete (elapsed: 0.13 seconds)
# [2026-08-07 17:50:09 INFO] completed processing PT-JPL-SM in 0.13 seconds
# [2026-08-07 17:50:09 INFO] variable LE_PTJPLSM_Wm2 min: 0.000 mean: 57.581 max: 789.186 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable ET_daylight_PTJPLSM_kg min: 0.000 mean: 0.626 max: 8.102 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable G_PTJPLSM min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable EF_PTJPLSM min: 0.000 mean: 0.338 max: 1.073 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_canopy_PTJPLSM_Wm2 min: 0.000 mean: 19.242 max: 342.070 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_canopy_fraction_PTJPLSM min: 0.000 mean: 0.313 max: 0.958 nan: 57.01% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_soil_PTJPLSM_Wm2 min: 0.000 mean: 29.337 max: 599.242 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_soil_fraction_PTJPLSM min: 0.000 mean: 0.519 max: 0.999 nan: 57.01% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_interception_PTJPLSM_Wm2 min: 0.000 mean: 9.002 max: 400.929 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_interception_fraction_PTJPLSM min: 0.000 mean: 0.168 max: 0.999 nan: 57.01% (nan)
# [2026-08-07 17:50:09 INFO] variable PET_instantaneous_PTJPLSM_Wm2 min: 0.000 mean: 62.503 max: 816.006 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable ESI_PTJPLSM min: 0.161 mean: 0.878 max: 1.000 nan: 57.01% (nan)
# [2026-08-07 17:50:09 INFO] running Penman-Monteith JPL
# [2026-08-07 17:50:09 INFO] variable Ta_C min: -14.499 mean: 12.553 max: 39.604 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable Tmin_C (float64) with [32.65892] unique values
# [2026-08-07 17:50:09 INFO] * 32.65892: 6144
# [2026-08-07 17:50:09 INFO] variable IGBP (float32) with [12.] unique values
# [2026-08-07 17:50:09 INFO] * 12.0: 6144
# [2026-08-07 17:50:09 INFO] using given net radiation (Rn_Wm2) for PM-JPL processing
# [2026-08-07 17:50:09 INFO] variable Rn_Wm2 min: 0.000 mean: 75.972 max: 803.032 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable G_Wm2 min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] calculating PM-MOD meteorology
# [2026-08-07 17:50:09 INFO] variable specific_humidity min: 0.001 mean: 0.007 max: 0.037 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable rho_kgm3 min: 1.116 mean: 1.556 max: 2.011 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable Cp_Jkg min: 1006.003 mean: 1011.192 max: 1035.834 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable delta_Pa min: 16.422 mean: 129.776 max: 384.586 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable fwet min: 0.000 mean: 0.212 max: 0.931 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] calculating PM-MOD resistances
# [2026-08-07 17:50:09 INFO] variable gl_sh (float32) with [0.02] unique values
# [2026-08-07 17:50:09 INFO] * 0.02: 6144
# [2026-08-07 17:50:09 INFO] variable rhc min: 12.890 mean: 1290.860 max: 2000.000 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable rrc min: 165.480 mean: 304.482 max: 504.386 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable rhrc min: 12.289 mean: 193.172 max: 402.683 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable gl_e_wv (float32) with [0.02] unique values
# [2026-08-07 17:50:09 INFO] * 0.02: 6144
# [2026-08-07 17:50:09 INFO] variable rvc min: 12.890 mean: 1290.860 max: 2000.000 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable Ac min: 0.000 mean: 57.400 max: 630.128 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_interception_Wm2 min: 0.000 mean: 15.350 max: 444.584 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable rcorr min: 0.901 mean: 1.328 max: 1.824 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable CL (float32) with [0.007] unique values
# [2026-08-07 17:50:09 INFO] * 0.007: 6144
# [2026-08-07 17:50:09 INFO] variable Tmin_open (float32) with [12.02] unique values
# [2026-08-07 17:50:09 INFO] * 12.02: 6144
# [2026-08-07 17:50:09 INFO] variable Tmin_closed (float32) with [-8.] unique values
# [2026-08-07 17:50:09 INFO] * -8.0: 6144
# [2026-08-07 17:50:09 INFO] variable Tmin_C (float64) with [32.65892] unique values
# [2026-08-07 17:50:09 INFO] * 32.65892: 6144
# [2026-08-07 17:50:09 INFO] variable mTmin (float64) with [1.] unique values
# [2026-08-07 17:50:09 INFO] * 1.0: 6144
# [2026-08-07 17:50:09 INFO] variable VPD_open (float32) with [650.] unique values
# [2026-08-07 17:50:09 INFO] * 650.0: 6144
# [2026-08-07 17:50:09 INFO] variable VPD_closed (float32) with [4500.] unique values
# [2026-08-07 17:50:09 INFO] * 4500.0: 6144
# [2026-08-07 17:50:09 INFO] variable mVPD min: 0.000 mean: 0.895 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable gs1 min: 0.000 mean: 0.008 max: 0.013 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable Gcu min: 0.000 mean: 0.000 max: 0.000 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable Cc min: 0.001 mean: 0.006 max: 0.035 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable rs min: 28.973 mean: 615.948 max: 2000.000 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable rh min: 28.973 mean: 615.948 max: 2000.000 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable rr min: 165.480 mean: 304.482 max: 504.386 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable ra min: 38.398 mean: 42.642 max: 45.491 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 56.909 max: 520.308 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable RBL_max (float32) with [50.] unique values
# [2026-08-07 17:50:09 INFO] * 50.0: 6144
# [2026-08-07 17:50:09 INFO] variable RBL_min (float32) with [20.] unique values
# [2026-08-07 17:50:09 INFO] * 20.0: 6144
# [2026-08-07 17:50:09 INFO] variable rtotc min: 20.000 mean: 46.838 max: 50.000 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable rtot min: 18.026 mean: 62.586 max: 91.191 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable rrs min: 165.480 mean: 304.482 max: 504.386 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable ras min: 16.256 mean: 51.815 max: 77.229 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable Asoil min: 0.000 mean: 17.314 max: 496.819 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable wet_soil_evaporation_Wm2 min: 0.000 mean: 4.664 max: 227.758 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable potential_soil_evaporation_Wm2 min: 0.000 mean: 38.791 max: 707.261 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable fSM min: 0.000 mean: 0.356 max: 0.998 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_soil_Wm2 min: 0.000 mean: 8.630 max: 312.475 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] variable LE_Wm2 min: 0.000 mean: 47.860 max: 540.463 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] started daylight ET upscaling (PMJPL)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# [2026-08-07 17:50:09 INFO] completed daylight ET upscaling (PMJPL)
# [2026-08-07 17:50:09 INFO] completed processing PM-JPL in 0.15 seconds
# [2026-08-07 17:50:09 INFO] variable LE_PMJPL_Wm2 min: 0.000 mean: 47.860 max: 540.463 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable ET_daylight_PMJPL_kg min: 0.000 mean: 0.523 max: 5.549 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable G_PMJPL_Wm2 min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:50:09 INFO] variable ET_daylight_kg min: 0.000 mean: 0.484 max: 6.834 nan: 0.00% (nan)
# [2026-08-07 17:50:09 INFO] JET table processing complete (1.286 seconds)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)

# %% [markdown]
# ## Analyze and Visualize Sobol Indices
# We extract the target array, analyze the outputs via the Sobol library, and map the First-Order and Total-Order variance percentages into a comparison chart.[cite: 1]

# %%
target_output = "ET_daylight_kg"
Y = processed_samples[target_output].values

# Calculate Sobol indices
Si = sobol.analyze(problem, Y, calc_second_order=True)

# Visualizing First-Order and Total-Order Indices
fig, ax = plt.subplots(figsize=(12, 6))
x = np.arange(len(input_variables))
width = 0.35

ax.bar(x - width/2, Si['S1'], width, label='S1 (First-order: Direct Variance)')
ax.bar(x + width/2, Si['ST'], width, label='ST (Total-order: Includes Interactions)')

ax.set_ylabel('Sobol Index', fontsize=12)
ax.set_title(f'Sobol Sensitivity Indices for {target_output}', fontsize=14)
ax.set_xticks(x)
ax.set_xticklabels(input_variables, rotation=45, ha='right')
ax.legend()
ax.grid(axis='y', linestyle='--', alpha=0.7)

plt.show()
