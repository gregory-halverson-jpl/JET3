# %% [markdown]
# # JET Global Sensitivity Analysis with SALib (Sobol Indices)
#
# This notebook performs a Global Sensitivity Analysis (GSA) of the JET ensemble using ECOSTRESS Collection 2 Cal-Val data and **Sobol indices** via the `SALib` package. It computes first-order ($S_1$) and total-order ($S_T$) indices to rigorously quantify the fractional variance each input variable contributes to model outputs like latent heat flux and evapotranspiration.

# %%
import sys
import os
sys.path.insert(0, os.path.abspath(os.path.join(os.path.dirname("__file__"), '..')))
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Import SALib modules for Global Sensitivity Analysis
from SALib.sample import saltelli
from SALib.analyze import sobol
from sklearn.metrics import r2_score, mean_squared_error

# Custom JET modules
from JET3 import process_JET_table, load_ECOv002_calval_JET_inputs

# %% [markdown]
# ## Configuration and Problem Setup
# Load the baseline data and dynamically define the physical boundaries based on the absolute minimum and maximum values of the dataset.

# %%
input_variables = [
    "ST_C", "NDVI", "albedo", "Ta_C", "RH", 
    "AOT", "COT", "vapor_gccm", "ozone_cm", 
    "elevation_m", "canopy_height_meters"
]

output_variables = [
    "Rn_Wm2", "ET_daylight_kg"
]

# Load baseline data first
input_df = load_ECOv002_calval_JET_inputs()

# Drop missing values from required inputs
input_df = input_df.dropna(subset=[var for var in input_variables if var in input_df.columns])

# Set bounds using the absolute minimum and maximum of the real data (no filtering applied)
input_min = {var: input_df[var].min() for var in input_variables if var in input_df.columns}
input_max = {var: input_df[var].max() for var in input_variables if var in input_df.columns}

print(f"Total valid rows without filtering: {len(input_df)}")
# Out:
# Total valid rows without filtering: 1061

# %%
processed_df = process_JET_table(input_df)
# Out:
# [2026-08-07 17:57:23 INFO] starting JET table processing
# [2026-08-07 17:57:23 INFO] started extracting geometry from JET input table
# [2026-08-07 17:57:23 INFO] completed extracting geometry from JET input table (0.010 seconds)
# [2026-08-07 17:57:23 INFO] started extracting time from JET input table
# [2026-08-07 17:57:23 INFO] completed extracting time from JET input table (0.002 seconds)
# [2026-08-07 17:57:23 INFO] running Forest Light Environmental Simulator
# 34/34 ━━━━━━━━━━━━━━━━━━━━ 0s 2ms/step
# [2026-08-07 17:57:23 INFO] completed processing FLiES-ANN in 0.17 seconds
# [2026-08-07 17:57:23 INFO] variable PAR_albedo min: 0.003 mean: 0.052 max: 0.681 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable NIR_albedo min: 0.028 mean: 0.164 max: 0.582 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable PAR_direct_Wm2 min: 4.617 mean: 266.198 max: 473.257 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable SWin_FLiES_ANN min: 104.662 mean: 715.359 max: 1153.185 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] running Breathing Earth System Simulator
# <class 'numpy.ndarray'>
# float32
# [2026-08-07 17:57:23 INFO] variable SZA_deg min: 8.815 mean: 44.911 max: 72.288 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable CI min: 0.184 mean: 0.278 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable elevation_m min: 1.000 mean: 991.759 max: 3504.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable NDVI_minimum min: -0.033 mean: 0.174 max: 0.591 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable NDVI_maximum min: 0.314 mean: 0.629 max: 0.918 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable C4_fraction min: 0.000 mean: 0.294 max: 0.939 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable carbon_uptake_efficiency min: 0.080 mean: 0.083 max: 0.090 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable kn min: 0.410 mean: 0.514 max: 0.710 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable peakVCmax_C3_μmolm2s1 min: 52.821 mean: 88.996 max: 140.723 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable peakVCmax_C4_μmolm2s1 min: 37.000 mean: 65.214 max: 120.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable ball_berry_slope_C3 min: 7.500 mean: 8.695 max: 9.500 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable ball_berry_slope_C4 min: 4.100 mean: 5.177 max: 5.800 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable ball_berry_intercept_C3 min: 0.005 mean: 0.009 max: 0.015 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable KG_climate (float32) with [1. 2. 3. 4. 5.] unique values
# [2026-08-07 17:57:23 INFO] * 1.0: 3
# [2026-08-07 17:57:23 INFO] * 2.0: 469
# [2026-08-07 17:57:23 INFO] * 3.0: 172
# [2026-08-07 17:57:23 INFO] * 4.0: 413
# [2026-08-07 17:57:23 INFO] * 5.0: 4
# [2026-08-07 17:57:23 INFO] variable canopy_height_meters min: 0.000 mean: 6.066 max: 30.192 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] All GEOS-5 FP inputs provided, no retrieval needed.
# [2026-08-07 17:57:23 INFO] variable canopy_temperature_C min: -14.430 mean: 29.057 max: 86.110 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable soil_temperature_C min: -14.430 mean: 29.057 max: 86.110 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] using given FLiES output as BESS parameters
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# [2026-08-07 17:57:23 INFO] variable Ps_Pa min: 64923.167 mean: 90433.558 max: 101313.196 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable VPD_Pa min: 9.430 mean: 1744.100 max: 4717.745 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable RH min: 0.273 mean: 0.427 max: 0.985 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable desTa min: 16.249 mean: 177.009 max: 387.676 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable ddesTa min: 1.197 mean: 9.176 max: 17.906 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable gamma min: 42.603 mean: 60.211 max: 68.164 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Cp min: 1005.693 mean: 1012.865 max: 1022.895 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable rhoa min: 0.776 mean: 1.067 max: 1.314 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable epsa min: 0.658 mean: 0.775 max: 0.971 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable R min: 10.363 mean: 104.507 max: 1000.000 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable Rc min: 10.363 mean: 104.507 max: 1000.000 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable Rs min: 5.182 mean: 52.254 max: 500.000 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable SFd min: 0.020 mean: 0.051 max: 0.083 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable SFd2 min: 0.157 mean: 0.331 max: 1.126 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable DL min: 7.316 mean: 11.464 max: 14.086 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Ra min: 409.311 mean: 901.931 max: 1276.344 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable fStress min: 0.007 mean: 0.295 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable VCmax_C3_sunlit_μmolm2s1 min: 1.804 mean: 39.339 max: 159.939 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable VCmax_C4_sunlit_μmolm2s1 min: 1.438 mean: 30.681 max: 148.721 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable VCmax_C3_shaded_μmolm2s1 min: 0.060 mean: 36.937 max: 264.371 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable VCmax_C4_shaded_μmolm2s1 min: 0.060 mean: 31.598 max: 264.371 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable PARDiff min: 18.773 mean: 48.236 max: 230.073 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable PARDir min: 4.617 mean: 266.198 max: 473.257 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable NIRDiff min: 0.000 mean: 32.435 max: 346.098 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable NIRDir min: 0.000 mean: 327.482 max: 591.598 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable UV min: 7.934 mean: 42.191 max: 76.912 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable SZA min: 8.815 mean: 44.911 max: 72.288 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable LAI min: 0.076 mean: 1.288 max: 4.516 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable CI min: 0.184 mean: 0.278 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable albedo_visible min: 0.003 mean: 0.052 max: 0.681 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable albedo_NIR min: 0.028 mean: 0.164 max: 0.582 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable kb min: 0.506 mean: 0.787 max: 1.643 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable kk_Pb min: 0.465 mean: 0.724 max: 1.512 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable kk_Nb min: 0.212 mean: 0.329 max: 0.688 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable kk_Nd (float64) with [0.1464155] unique values
# [2026-08-07 17:57:23 INFO] * 0.14641550464346323: 1
# [2026-08-07 17:57:23 INFO] variable fSun min: 0.118 mean: 0.240 max: 0.580 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable L_CI min: 0.021 mean: 0.375 max: 3.967 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable exp_kk_Pd_L_CI min: 0.057 mean: 0.794 max: 0.985 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable exp_kk_Nd_L_CI min: 0.559 mean: 0.949 max: 0.997 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APARin_Wm2 min: 2.063 mean: 57.508 max: 359.813 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APARin_sunlit_Wm2 min: 0.675 mean: 42.969 max: 277.576 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APARin_diffuse_Wm2 min: 0.452 mean: 8.649 max: 84.560 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APARin_scattered_sunlit_Wm2 min: 0.000 mean: 3.066 max: 21.749 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APARin_sunlit_Wm2 min: 2.317 mean: 54.684 max: 320.565 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APARin_shade_Wm2 min: 0.000 mean: 2.846 max: 66.276 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable PARin_soil_Wm2 min: 8.308 mean: 240.644 max: 435.252 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APAR_Soil min: 7.062 mean: 204.547 max: 369.964 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APARout_sunlit_Wm2 min: 0.072 mean: 29.869 max: 63.128 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APARout_shade_Wm2 min: 0.282 mean: 6.228 max: 21.729 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APAR_sunlit_Wm2 min: 14.354 mean: 84.553 max: 321.081 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APAR_shade_Wm2 min: 0.282 mean: 9.074 max: 69.821 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ANIRin_sunlit_Wm2 min: 0.470 mean: 23.266 max: 142.775 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ANIRin_shade_Wm2 min: 0.004 mean: 3.498 max: 91.295 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable NIRin_soil_Wm2 min: 33.725 mean: 274.738 max: 483.909 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ANIR_soil_Wm2 min: 23.607 mean: 192.316 max: 338.736 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ANIRout_sunlit_Wm2 min: 7.809 mean: 78.802 max: 142.395 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ANIRout_Wm2 min: 0.140 mean: 3.619 max: 21.642 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ANIR_sunlit_Wm2 min: 11.150 mean: 102.068 max: 177.798 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ANIR_shade_Wm2 min: 0.144 mean: 7.116 max: 109.415 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable G_Wm2 min: 1.977 mean: 57.273 max: 103.590 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ASW_sunlit_Wm2 min: 26.703 mean: 187.250 max: 492.419 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ASW_shade_Wm2 min: 0.736 mean: 18.260 max: 179.098 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ASW_soil_Wm2 min: 50.151 mean: 434.266 max: 772.766 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APAR_sunlit_Wm2 min: 14.354 mean: 84.553 max: 321.081 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APAR_sunlit_μmolm2s1 min: 65.455 mean: 385.560 max: 1464.128 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APAR_shade_Wm2 min: 0.282 mean: 9.074 max: 69.821 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APAR_shade_μmolm2s1 min: 1.285 mean: 41.378 max: 318.384 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable fSun min: 0.118 mean: 0.240 max: 0.580 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APAR_sunlit_μmolm2s1 min: 65.455 mean: 385.560 max: 1464.128 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable APAR_shade_μmolm2s1 min: 1.285 mean: 41.378 max: 318.384 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ASW_sunlit_Wm2 min: 26.703 mean: 187.250 max: 492.419 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ASW_shade_Wm2 min: 0.736 mean: 18.260 max: 179.098 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ASW_soil_Wm2 min: 50.151 mean: 434.266 max: 772.766 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable G_Wm2 min: 1.977 mean: 57.273 max: 103.590 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable GPP_C3 min: 0.000 mean: 9.096 max: 40.000 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_C3 min: 0.000 mean: 111.056 max: 445.212 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_soil_C3 min: 0.000 mean: 51.179 max: 237.539 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_canopy_C3 min: 0.000 mean: 59.877 max: 401.873 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Rn_C3 min: 0.000 mean: 452.112 max: 936.404 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Rn_soil_C3 min: 0.000 mean: 340.939 max: 645.712 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Rn_canopy_C3 min: 0.000 mean: 111.173 max: 548.249 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable GPP_C4 min: 0.000 mean: 13.297 max: 50.000 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_C4 min: 0.000 mean: 112.878 max: 475.523 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_soil_C4 min: 0.000 mean: 51.179 max: 237.539 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_canopy_C4 min: 0.000 mean: 61.699 max: 432.184 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Rn_C4 min: 0.000 mean: 452.112 max: 936.404 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Rn_soil_C4 min: 0.000 mean: 340.939 max: 645.712 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Rn_canopy_C4 min: 0.000 mean: 111.173 max: 548.249 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] started daylight ET upscaling
# [2026-08-07 17:57:23 INFO] completed daylight ET upscaling (elapsed: 0.03 seconds)
# [2026-08-07 17:57:23 INFO] completed processing BESS-JPL in 0.14 seconds
# [2026-08-07 17:57:23 INFO] variable Rn_BESS_Wm2 min: 0.000 mean: 452.112 max: 936.404 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Rn_BESS_Wm2 min: 0.000 mean: 452.112 max: 936.404 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_BESS_Wm2 min: 0.000 mean: 111.967 max: 445.443 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] calculating solar day of year
# [2026-08-07 17:57:23 INFO] calculating solar hour of day
# [2026-08-07 17:57:23 INFO] calculating daylight hours and sunrise hour
# [2026-08-07 17:57:23 INFO] variable LE_BESS_Wm2 min: 0.000 mean: 111.967 max: 445.443 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable GPP_inst_umol_m2_s min: 0.000 mean: 9.839 max: 42.940 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] starting Verma net radiation processing
# [2026-08-07 17:57:23 INFO] variable SWout_Wm2 min: 5.851 mean: 78.455 max: 337.308 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable SWnet_Wm2 min: 94.946 mean: 636.904 max: 1017.082 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable LWin_Wm2 min: 175.737 mean: 343.784 max: 473.521 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable LWout_Wm2 min: 240.846 mean: 462.454 max: 693.334 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Rn_Wm2 min: 0.000 mean: 518.409 max: 965.202 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] Verma net radiation processing complete in 0.00 seconds
# [2026-08-07 17:57:23 INFO] running Surface Temperature Initiated Closure
# [2026-08-07 17:57:23 INFO] variable Ms min: 0.000 mean: 0.229 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] running STIC iteration 1 / 3
# [2026-08-07 17:57:23 INFO] using variable Priestley-Taylor alpha with mean: 1.264
# [2026-08-07 17:57:23 INFO] completed STIC iteration 1 / 3 with max LE change: 316.084 (0.001312457985477522 seconds)
# [2026-08-07 17:57:23 INFO] variable SM_1 min: 0.000 mean: 0.143 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable G_1 min: 0.000 mean: 65.311 max: 222.087 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_1 min: 0.000 mean: 248.988 max: 746.899 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] running STIC iteration 2 / 3
# [2026-08-07 17:57:23 INFO] using variable Priestley-Taylor alpha with mean: 1.535
# [2026-08-07 17:57:23 INFO] completed STIC iteration 2 / 3 with max LE change: 91.852 (0.004684666986577213 seconds)
# [2026-08-07 17:57:23 INFO] variable SM_2 min: 0.000 mean: 0.146 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable G_2 min: 0.000 mean: 65.311 max: 222.087 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_2 min: 0.000 mean: 251.980 max: 755.638 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] running STIC iteration 3 / 3
# [2026-08-07 17:57:23 INFO] using variable Priestley-Taylor alpha with mean: 2.222
# [2026-08-07 17:57:23 INFO] completed STIC iteration 3 / 3 with max LE change: 54.96 (0.007375541987130418 seconds)
# [2026-08-07 17:57:23 INFO] variable SM_3 min: 0.000 mean: 0.143 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable G_3 min: 0.000 mean: 65.311 max: 222.087 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_3 min: 0.000 mean: 254.365 max: 762.748 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] started daily ET upscaling (STIC-JPL)
# [2026-08-07 17:57:23 INFO] completed daily ET upscaling (elapsed: 0.02 seconds)
# [2026-08-07 17:57:23 INFO] completed processing STIC-JPL in 0.05 seconds
# [2026-08-07 17:57:23 INFO] variable LE_STIC_Wm2 min: 0.000 mean: 254.365 max: 762.748 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ET_daylight_STIC_kg min: 0.000 mean: 3.524 max: 8.821 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_canoy_STIC_Wm2 min: 0.000 mean: 184.142 max: 569.703 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable G_STIC_Wm2 min: 0.000 mean: 65.311 max: 222.087 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_canopy_fraction_STIC min: 0.000 mean: 0.737 max: 1.000 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] running Priestley-Taylor JPL with Soil Moisture
# [2026-08-07 17:57:23 INFO] starting PT-JPL-SM model run
# [2026-08-07 17:57:23 INFO] using given optimum temperature (Topt_C)
# [2026-08-07 17:57:23 INFO] variable Topt_C min: 0.000 mean: 8.128 max: 23.210 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable fAPARmax min: 0.233 mean: 0.382 max: 0.624 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] using given air temperature (Ta_C)
# [2026-08-07 17:57:23 INFO] variable Ta_C min: -14.605 mean: 22.337 max: 39.710 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] using given relative humidity (RH)
# [2026-08-07 17:57:23 INFO] variable RH min: 0.273 mean: 0.427 max: 0.984 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] using given soil moisture (SM)
# [2026-08-07 17:57:23 INFO] variable soil_moisture min: 0.000 mean: 0.168 max: 0.897 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] using given field capacity
# [2026-08-07 17:57:23 INFO] variable field_capacity min: 0.190 mean: 0.283 max: 0.390 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] using given wilting point
# [2026-08-07 17:57:23 INFO] variable wilting_point min: 0.040 mean: 0.121 max: 0.290 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] using given canopy height
# [2026-08-07 17:57:23 INFO] variable canopy_height_meters min: 0.000 mean: 6.066 max: 30.192 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] using given net radiation (Rn_Wm2) for PT-JPL-SM processing
# [2026-08-07 17:57:23 INFO] variable Rn_Wm2 min: 0.000 mean: 518.409 max: 965.202 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] using given soil heat flux (G_Wm2)
# [2026-08-07 17:57:23 INFO] variable G min: 0.000 mean: 65.311 max: 222.087 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable fwet min: 0.006 mean: 0.055 max: 0.936 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable fREW min: 0.000 mean: 0.457 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Topt_C min: 0.000 mean: 8.128 max: 23.210 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Topt_C min: 0.100 mean: 22.790 max: 39.710 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable epsilon min: 0.198 mean: 0.701 max: 0.854 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Rn_soil_Wm2 min: 0.000 mean: 281.387 max: 673.620 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_soil_Wm2 min: 0.000 mean: 61.168 max: 387.894 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable Rn_canopy_Wm2 min: 0.000 mean: 237.698 max: 803.207 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable PET min: 0.000 mean: 406.129 max: 911.997 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable fTRM min: 0.000 mean: 0.812 max: 1.000 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 150.803 max: 573.102 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_interception_Wm2 min: 0.000 mean: 12.555 max: 123.593 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_Wm2 min: 0.000 mean: 224.526 max: 678.968 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] started daylight ET upscaling
# [2026-08-07 17:57:23 INFO] completed daylight ET upscaling (elapsed: 0.03 seconds)
# [2026-08-07 17:57:23 INFO] PT-JPL-SM model run complete (elapsed: 0.04 seconds)
# [2026-08-07 17:57:23 INFO] completed processing PT-JPL-SM in 0.04 seconds
# [2026-08-07 17:57:23 INFO] variable LE_PTJPLSM_Wm2 min: 0.000 mean: 224.526 max: 678.968 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ET_daylight_PTJPLSM_kg min: 0.000 mean: 3.042 max: 8.370 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable G_PTJPLSM min: 0.000 mean: 65.311 max: 222.087 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable EF_PTJPLSM min: 0.000 mean: 0.478 max: 0.994 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_canopy_PTJPLSM_Wm2 min: 0.000 mean: 150.803 max: 573.102 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_canopy_fraction_PTJPLSM min: 0.000 mean: 0.703 max: 0.984 nan: 0.38% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_soil_PTJPLSM_Wm2 min: 0.000 mean: 61.168 max: 387.894 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_soil_fraction_PTJPLSM min: 0.002 mean: 0.243 max: 0.995 nan: 0.38% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_interception_PTJPLSM_Wm2 min: 0.000 mean: 12.555 max: 123.593 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_interception_fraction_PTJPLSM min: 0.001 mean: 0.053 max: 0.810 nan: 0.38% (nan)
# [2026-08-07 17:57:23 INFO] variable PET_instantaneous_PTJPLSM_Wm2 min: 0.000 mean: 406.129 max: 911.997 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ESI_PTJPLSM min: 0.067 mean: 0.550 max: 1.000 nan: 0.38% (nan)
# [2026-08-07 17:57:23 INFO] running Penman-Monteith JPL
# [2026-08-07 17:57:23 INFO] variable Ta_C min: -14.605 mean: 22.337 max: 39.710 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Tmin_C min: 0.122 mean: 8.387 max: 32.659 nan: 1.70% (nan)
# [2026-08-07 17:57:23 INFO] variable IGBP min: -1.000 mean: 7.789 max: 13.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] using given net radiation (Rn_Wm2) for PM-JPL processing
# [2026-08-07 17:57:23 INFO] variable Rn_Wm2 min: 0.000 mean: 518.409 max: 965.202 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable G_Wm2 min: 0.000 mean: 65.311 max: 222.087 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] calculating PM-MOD meteorology
# [2026-08-07 17:57:23 INFO] variable specific_humidity min: 0.001 mean: 0.007 max: 0.019 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable rho_kgm3 min: 1.138 mean: 1.365 max: 1.938 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Cp_Jkg min: 1006.238 mean: 1010.749 max: 1020.562 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable delta_Pa min: 16.294 mean: 176.655 max: 386.473 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable fwet min: 0.000 mean: 0.015 max: 0.936 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] calculating PM-MOD resistances
# [2026-08-07 17:57:23 INFO] variable gl_sh (float32) with [0.01 0.02 0.04 0.08] unique values
# [2026-08-07 17:57:23 INFO] * 0.01: 131
# [2026-08-07 17:57:23 INFO] * 0.02: 498
# [2026-08-07 17:57:23 INFO] * 0.04: 285
# [2026-08-07 17:57:23 INFO] * 0.08: 147
# [2026-08-07 17:57:23 INFO] variable rhc min: 11.696 mean: 1934.880 max: 2000.000 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable rrc min: 173.391 mean: 237.083 max: 444.191 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable rhrc min: 11.163 mean: 205.994 max: 363.467 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable gl_e_wv (float32) with [0.01 0.02 0.04 0.08] unique values
# [2026-08-07 17:57:23 INFO] * 0.01: 131
# [2026-08-07 17:57:23 INFO] * 0.02: 498
# [2026-08-07 17:57:23 INFO] * 0.04: 285
# [2026-08-07 17:57:23 INFO] * 0.08: 147
# [2026-08-07 17:57:23 INFO] variable rvc min: 11.696 mean: 1934.880 max: 2000.000 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable Ac min: 0.000 mean: 362.303 max: 965.202 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_interception_Wm2 min: 0.001 mean: 2.813 max: 223.096 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable rcorr min: 0.917 mean: 1.132 max: 1.665 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable CL (float32) with [0.0025 0.0028 0.0032 0.0065 0.007 ] unique values
# [2026-08-07 17:57:23 INFO] * 0.0025: 37
# [2026-08-07 17:57:23 INFO] * 0.0028: 131
# [2026-08-07 17:57:23 INFO] * 0.0032: 62
# [2026-08-07 17:57:23 INFO] * 0.0065: 333
# [2026-08-07 17:57:23 INFO] * 0.007: 498
# [2026-08-07 17:57:23 INFO] variable Tmin_open (float32) with [ 8.31  8.8   9.5   9.94 11.39 12.02] unique values
# [2026-08-07 17:57:23 INFO] * 8.31: 62
# [2026-08-07 17:57:23 INFO] * 8.8: 186
# [2026-08-07 17:57:23 INFO] * 9.5: 37
# [2026-08-07 17:57:23 INFO] * 9.94: 131
# [2026-08-07 17:57:23 INFO] * 11.39: 147
# [2026-08-07 17:57:23 INFO] * 12.02: 498
# [2026-08-07 17:57:23 INFO] variable Tmin_closed (float32) with [-8. -7. -6.] unique values
# [2026-08-07 17:57:23 INFO] * -8.0: 893
# [2026-08-07 17:57:23 INFO] * -7.0: 37
# [2026-08-07 17:57:23 INFO] * -6.0: 131
# [2026-08-07 17:57:23 INFO] variable Tmin_C min: 0.122 mean: 8.387 max: 32.659 nan: 1.70% (nan)
# [2026-08-07 17:57:23 INFO] variable mTmin min: 0.384 mean: 0.821 max: 1.000 nan: 1.70% (nan)
# [2026-08-07 17:57:23 INFO] variable VPD_open (float32) with [650.] unique values
# [2026-08-07 17:57:23 INFO] * 650.0: 1061
# [2026-08-07 17:57:23 INFO] variable VPD_closed (float32) with [2900. 3000. 3500. 3600. 4200. 4400. 4500.] unique values
# [2026-08-07 17:57:23 INFO] * 2900.0: 168
# [2026-08-07 17:57:23 INFO] * 3000.0: 62
# [2026-08-07 17:57:23 INFO] * 3500.0: 90
# [2026-08-07 17:57:23 INFO] * 3600.0: 57
# [2026-08-07 17:57:23 INFO] * 4200.0: 393
# [2026-08-07 17:57:23 INFO] * 4400.0: 186
# [2026-08-07 17:57:23 INFO] * 4500.0: 105
# [2026-08-07 17:57:23 INFO] variable mVPD min: 0.000 mean: 0.661 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable gs1 min: 0.000 mean: 0.004 max: 0.010 nan: 1.70% (nan)
# [2026-08-07 17:57:23 INFO] variable Gcu min: 0.000 mean: 0.000 max: 0.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Cc min: 0.001 mean: 0.004 max: 0.022 nan: 1.70% (nan)
# [2026-08-07 17:57:23 INFO] variable rs min: 46.041 mean: 650.740 max: 2000.000 nan: 1.70% (nan)
# [2026-08-07 17:57:23 INFO] variable rh min: 46.041 mean: 650.740 max: 2000.000 nan: 1.70% (nan)
# [2026-08-07 17:57:23 INFO] variable rr min: 173.391 mean: 237.083 max: 444.191 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable ra min: 11.659 mean: 35.619 max: 78.750 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 129.623 max: 559.970 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable RBL_max (float32) with [ 45.  50.  55.  95. 100.] unique values
# [2026-08-07 17:57:23 INFO] * 45.0: 147
# [2026-08-07 17:57:23 INFO] * 50.0: 498
# [2026-08-07 17:57:23 INFO] * 55.0: 186
# [2026-08-07 17:57:23 INFO] * 95.0: 99
# [2026-08-07 17:57:23 INFO] * 100.0: 131
# [2026-08-07 17:57:23 INFO] variable RBL_min (float32) with [20. 25. 65.] unique values
# [2026-08-07 17:57:23 INFO] * 20.0: 684
# [2026-08-07 17:57:23 INFO] * 25.0: 147
# [2026-08-07 17:57:23 INFO] * 65.0: 230
# [2026-08-07 17:57:23 INFO] variable rtotc min: 20.000 mean: 50.226 max: 100.000 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable rtot min: 19.282 mean: 56.394 max: 131.901 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable rrs min: 173.391 mean: 237.083 max: 444.191 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable ras min: 17.391 mean: 44.577 max: 97.278 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable Asoil min: 0.000 mean: 108.812 max: 461.811 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable wet_soil_evaporation_Wm2 min: 0.000 mean: 0.371 max: 79.668 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable potential_soil_evaporation_Wm2 min: 0.000 mean: 158.832 max: 786.286 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable fSM min: 0.000 mean: 0.043 max: 0.999 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_soil_Wm2 min: 0.000 mean: 1.447 max: 99.518 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] variable LE_Wm2 min: 0.000 mean: 133.268 max: 559.998 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] started daylight ET upscaling (PMJPL)
# [2026-08-07 17:57:23 INFO] completed daylight ET upscaling (PMJPL)
# [2026-08-07 17:57:23 INFO] completed processing PM-JPL in 0.08 seconds
# [2026-08-07 17:57:23 INFO] variable LE_PMJPL_Wm2 min: 0.000 mean: 133.268 max: 559.998 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ET_daylight_PMJPL_kg min: 0.000 mean: 1.856 max: 7.137 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable G_PMJPL_Wm2 min: 0.000 mean: 65.311 max: 222.087 nan: 0.19% (nan)
# [2026-08-07 17:57:23 INFO] variable ET_daylight_kg min: 0.000 mean: 2.372 max: 7.164 nan: 0.00% (nan)
# [2026-08-07 17:57:23 INFO] JET table processing complete (0.531 seconds)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)

# %% [markdown]
# ## Analyze Baseline Data In-Situ Accuracy

# %%
import seaborn as sns

# Set Seaborn style for prettier plots
sns.set_theme(style="whitegrid", palette="muted")

def plot_insitu_accuracy(df, variable_name, color=None, model_name=None, cmap="viridis"):
    """
    Generates a scatter plot comparing a single in-situ variable to its model equivalent.
    """
    try:
        insitu_variable = f"insitu_{variable_name}"
        model_prefix = f"{model_name} " if model_name else ""
        print(f"Analyzing {model_prefix}accuracy for {variable_name} compared to {insitu_variable}")
        
        x_variable = insitu_variable
        y_variable = variable_name

        # Check if required columns exist
        required_cols = [x_variable, y_variable]
        if color and color in df.columns:
            required_cols.append(color)
            
        missing_cols = [col for col in required_cols if col not in df.columns]
        if missing_cols:
            raise KeyError(f"Missing required columns in dataframe: {missing_cols}")

        # Filter out rows with NaN values in relevant variables
        valid_data = df[required_cols].dropna()
        
        if valid_data.empty:
            print(f"No valid data remaining after dropping NaNs for {variable_name}. Skipping.")
            return

        # Initialize figure
        plt.figure(figsize=(8, 6))
        
        sc = plt.scatter(
            x=valid_data[x_variable],
            y=valid_data[y_variable],
            c=valid_data[color] if color is not None else None,
            cmap=cmap,
            s=15,
            edgecolor="none",
            alpha=0.8
        )

        # Calculate OLS regression line coefficients
        coefs = np.polyfit(valid_data[x_variable], valid_data[y_variable], 1)

        # Add 1-to-1 line across the entire axis
        plt.axline((0, 0), slope=1, color='gray', linestyle='-', linewidth=1.5, label='1:1 Line')

        # Add OLS regression line across the entire axis
        plt.axline((0, coefs[1]), slope=coefs[0], color='#d62728', linestyle='--', linewidth=2, label='OLS Fit')

        # Calculate R-squared and RMSE
        y_true = valid_data[y_variable]
        y_pred = coefs[0] * valid_data[x_variable] + coefs[1]
        r2 = r2_score(y_true, y_pred)
        rmse = np.sqrt(mean_squared_error(y_true, y_pred))

        # Annotate R-squared and RMSE on plot in lower left corner
        plt.annotate(f"$R^2$ = {r2:.2f}\nRMSE = {rmse:.1f}",
                    xy=(0.05, 0.05), xycoords='axes fraction',
                    ha='left', va='bottom',
                    fontsize=11,
                    bbox=dict(boxstyle='round,pad=0.4', fc='white', ec='lightgray', alpha=0.9))

        # Formatting
        plt.xlabel(f"In-Situ {variable_name}", fontsize=11, weight='bold')
        plt.ylabel(f"{model_prefix}{variable_name}", fontsize=11, weight='bold')
        plt.title(f"Accuracy Comparison\nIn-Situ {variable_name} vs {model_prefix}{variable_name}", fontsize=14, weight='bold')
        
        if color:
            plt.colorbar(sc, label=f"{color} Value")
            
        plt.legend(loc='upper left', frameon=True)
        sns.despine(left=True, bottom=True)
        plt.tight_layout()
        plt.show()
        plt.close() # Free memory after displaying
        
    except Exception as e:
        print(f"Error processing {insitu_variable}: {e}")

# %%
# Generate accuracy plot for Ta_C
plot_insitu_accuracy(processed_df, variable_name="Ta_C", color="ST_C")
# Out:
# Analyzing accuracy for Ta_C compared to insitu_Ta_C

# %%
# Generate requested accuracy plot for ET_daylight_kg
plot_insitu_accuracy(processed_df, variable_name="ET_daylight_kg", color="ST_C")
# Out:
# Analyzing accuracy for ET_daylight_kg compared to insitu_ET_daylight_kg

# %% [markdown]
# ## Generate Saltelli Samples
# Construct the problem dictionary and utilize Saltelli's extension of the Sobol sequence to generate parameter values.

# %%
problem = {
    'num_vars': len(input_variables),
    'names': input_variables,
    'bounds': [[input_min[var], input_max[var]] for var in input_variables]
}

# Generate Saltelli samples. Total iterations = N * (2D + 2)
# With D=11 and N=256, total model evaluations will be 6,144.
N = 256 
param_values = saltelli.sample(problem, N, calc_second_order=True)
# Out:
# /var/folders/bv/410kt7f93x78j9dww00h1pz80000gn/T/ipykernel_74644/65101988.py:10: DeprecationWarning: `salib.sample.saltelli` will be removed in SALib 1.5.1 Please use `salib.sample.sobol`
#   param_values = saltelli.sample(problem, N, calc_second_order=True)

# %% [markdown]
# ## Process Samples via the JET Model
# We broadcast a static base row from the dataframe to match the Saltelli matrix size, overwrite our input variables with the generated samples, and execute the forward run.

# %%
# Construct a sampled DataFrame by repeating a base row
base_row = input_df.iloc[0:1]
sampled_df = pd.concat([base_row] * param_values.shape[0], ignore_index=True)

# Inject the perturbed Sobol variables into the DataFrame
sampled_df[input_variables] = param_values
print(f"Executing {param_values.shape[0]} runs for Global Sensitivity Analysis...")

# Run the forward process
processed_samples = process_JET_table(sampled_df)
# Out:
# Executing 6144 runs for Global Sensitivity Analysis...
# [2026-08-07 17:55:44 INFO] starting JET table processing
# [2026-08-07 17:55:45 INFO] started extracting geometry from JET input table
# [2026-08-07 17:55:45 INFO] completed extracting geometry from JET input table (0.038 seconds)
# [2026-08-07 17:55:45 INFO] started extracting time from JET input table
# [2026-08-07 17:55:45 INFO] completed extracting time from JET input table (0.003 seconds)
# [2026-08-07 17:55:45 INFO] running Forest Light Environmental Simulator
# 192/192 ━━━━━━━━━━━━━━━━━━━━ 0s 254us/step
# [2026-08-07 17:55:45 INFO] completed processing FLiES-ANN in 0.40 seconds
# [2026-08-07 17:55:45 INFO] variable PAR_albedo (float64) with [0.09390986] unique values
# [2026-08-07 17:55:45 INFO] * 0.0939098562443398: 6144
# [2026-08-07 17:55:45 INFO] variable NIR_albedo (float64) with [0.35587504] unique values
# [2026-08-07 17:55:45 INFO] * 0.3558750381101216: 6144
# [2026-08-07 17:55:45 INFO] variable PAR_direct_Wm2 min: 2.934 mean: 26.668 max: 263.589 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable SWin_FLiES_ANN min: 65.389 mean: 263.056 max: 750.835 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] running Breathing Earth System Simulator
# <class 'numpy.ndarray'>
# float32
# [2026-08-07 17:55:45 INFO] variable SZA_deg (float32) with [48.498672] unique values
# [2026-08-07 17:55:45 INFO] * 48.498672: 6144
# [2026-08-07 17:55:45 INFO] variable CI (float64) with [0.28235294] unique values
# [2026-08-07 17:55:45 INFO] * 0.2823529411764706: 6144
# [2026-08-07 17:55:45 INFO] variable elevation_m min: 7.842 mean: 1752.500 max: 3497.158 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable NDVI_minimum (float64) with [0.40873316] unique values
# [2026-08-07 17:55:45 INFO] * 0.4087331578417219: 6144
# [2026-08-07 17:55:45 INFO] variable NDVI_maximum (float64) with [0.8556929] unique values
# [2026-08-07 17:55:45 INFO] * 0.8556928956658199: 6144
# [2026-08-07 17:55:45 INFO] variable C4_fraction (float64) with [0.07753171] unique values
# [2026-08-07 17:55:45 INFO] * 0.0775317136278871: 6144
# [2026-08-07 17:55:45 INFO] variable carbon_uptake_efficiency (float64) with [0.08] unique values
# [2026-08-07 17:55:45 INFO] * 0.0799999982118606: 6144
# [2026-08-07 17:55:45 INFO] variable kn (float64) with [0.41] unique values
# [2026-08-07 17:55:45 INFO] * 0.4099999964237213: 6144
# [2026-08-07 17:55:45 INFO] variable peakVCmax_C3_μmolm2s1 (float64) with [87.34543335] unique values
# [2026-08-07 17:55:45 INFO] * 87.34543334528844: 6144
# [2026-08-07 17:55:45 INFO] variable peakVCmax_C4_μmolm2s1 (float64) with [51.04062441] unique values
# [2026-08-07 17:55:45 INFO] * 51.04062440664798: 6144
# [2026-08-07 17:55:45 INFO] variable ball_berry_slope_C3 (float64) with [9.5] unique values
# [2026-08-07 17:55:45 INFO] * 9.5: 6144
# [2026-08-07 17:55:45 INFO] variable ball_berry_slope_C4 (float64) with [4.9519627] unique values
# [2026-08-07 17:55:45 INFO] * 4.951962701536608: 6144
# [2026-08-07 17:55:45 INFO] variable ball_berry_intercept_C3 (float64) with [0.00526687] unique values
# [2026-08-07 17:55:45 INFO] * 0.0052668737343494: 6144
# [2026-08-07 17:55:45 INFO] variable KG_climate (float32) with [3.] unique values
# [2026-08-07 17:55:45 INFO] * 3.0: 6144
# [2026-08-07 17:55:45 INFO] variable canopy_height_meters min: 0.059 mean: 15.096 max: 30.133 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] All GEOS-5 FP inputs provided, no retrieval needed.
# [2026-08-07 17:55:45 INFO] variable canopy_temperature_C min: -14.234 mean: 35.840 max: 85.914 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable soil_temperature_C min: -14.234 mean: 35.840 max: 85.914 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] using given FLiES output as BESS parameters
# [2026-08-07 17:55:45 INFO] variable Ps_Pa min: 62986.012 mean: 82296.182 max: 101232.443 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable VPD_Pa min: 5.199 mean: 812.458 max: 4859.613 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable RH min: 0.274 mean: 0.628 max: 0.982 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable desTa min: 16.377 mean: 130.013 max: 385.780 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable ddesTa min: 1.205 mean: 6.838 max: 17.833 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable gamma min: 40.656 mean: 54.299 max: 68.312 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable Cp min: 1005.450 mean: 1014.339 max: 1058.977 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable rhoa min: 0.762 mean: 1.006 max: 1.348 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable epsa min: 0.671 mean: 0.910 max: 0.999 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable R min: 21.065 mean: 41.899 max: 110.557 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable Rc min: 21.065 mean: 41.899 max: 110.557 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable Rs min: 10.532 mean: 20.949 max: 55.278 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable SFd (float64) with [0.05905949] unique values
# [2026-08-07 17:55:45 INFO] * 0.05905948789791865: 6144
# [2026-08-07 17:55:45 INFO] variable SFd2 (float64) with [0.24941134] unique values
# [2026-08-07 17:55:45 INFO] * 0.2494113382413926: 6144
# [2026-08-07 17:55:45 INFO] variable DL (float64) with [10.04591982] unique values
# [2026-08-07 17:55:45 INFO] * 10.045919816401328: 6144
# [2026-08-07 17:55:45 INFO] variable Ra (float64) with [884.32062362] unique values
# [2026-08-07 17:55:45 INFO] * 884.3206236236358: 6144
# [2026-08-07 17:55:45 INFO] variable fStress min: 0.003 mean: 0.705 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable VCmax_C3_sunlit_μmolm2s1 min: 0.469 mean: 35.225 max: 100.906 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable VCmax_C4_sunlit_μmolm2s1 min: 0.274 mean: 20.584 max: 58.965 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable VCmax_C3_shaded_μmolm2s1 min: 0.004 mean: 39.768 max: 220.142 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable VCmax_C4_shaded_μmolm2s1 min: 0.002 mean: 23.238 max: 128.641 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable PARDiff min: 31.100 mean: 99.124 max: 172.490 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable PARDir min: 2.934 mean: 26.668 max: 263.589 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable NIRDiff min: 25.406 mean: 116.438 max: 291.646 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable NIRDir min: 0.000 mean: 3.663 max: 273.826 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable UV min: 4.663 mean: 16.934 max: 47.008 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable SZA (float32) with [48.498672] unique values
# [2026-08-07 17:55:45 INFO] * 48.498672: 6144
# [2026-08-07 17:55:45 INFO] variable LAI min: 0.022 mean: 1.488 max: 4.480 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable CI (float64) with [0.28235294] unique values
# [2026-08-07 17:55:45 INFO] * 0.2823529411764706: 6144
# [2026-08-07 17:55:45 INFO] variable albedo_visible (float64) with [0.09390986] unique values
# [2026-08-07 17:55:45 INFO] * 0.0939098562443398: 6144
# [2026-08-07 17:55:45 INFO] variable albedo_NIR (float64) with [0.35587504] unique values
# [2026-08-07 17:55:45 INFO] * 0.3558750381101216: 6144
# [2026-08-07 17:55:45 INFO] variable kb (float32) with [0.75456053] unique values
# [2026-08-07 17:55:45 INFO] * 0.75456053: 6144
# [2026-08-07 17:55:45 INFO] variable kk_Pb (float32) with [0.6941957] unique values
# [2026-08-07 17:55:45 INFO] * 0.6941957: 6144
# [2026-08-07 17:55:45 INFO] variable kk_Nb (float64) with [0.31565532] unique values
# [2026-08-07 17:55:45 INFO] * 0.31565531660336676: 6144
# [2026-08-07 17:55:45 INFO] variable kk_Nd (float64) with [0.1464155] unique values
# [2026-08-07 17:55:45 INFO] * 0.14641550464346323: 1
# [2026-08-07 17:55:45 INFO] variable fSun min: 0.182 mean: 0.244 max: 0.282 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable L_CI min: 0.006 mean: 0.420 max: 1.265 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable exp_kk_Pd_L_CI min: 0.402 mean: 0.758 max: 0.996 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable exp_kk_Nd_L_CI min: 0.831 mean: 0.941 max: 0.999 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APARin_Wm2 min: 0.203 mean: 27.414 max: 145.028 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APARin_sunlit_Wm2 min: 0.017 mean: 5.677 max: 98.347 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APARin_diffuse_Wm2 min: 0.186 mean: 17.641 max: 58.986 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APARin_scattered_sunlit_Wm2 min: 0.000 mean: 0.119 max: 2.516 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APARin_sunlit_Wm2 min: 0.203 mean: 23.438 max: 130.755 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APARin_shade_Wm2 min: 0.000 mean: 3.977 max: 24.861 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable PARin_soil_Wm2 min: 16.539 mean: 86.142 max: 268.408 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APAR_Soil min: 14.058 mean: 73.221 max: 228.147 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APARout_sunlit_Wm2 min: 1.012 mean: 10.228 max: 38.607 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APARout_shade_Wm2 min: 0.030 mean: 2.693 max: 10.160 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APAR_sunlit_Wm2 min: 5.455 mean: 33.666 max: 139.078 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APAR_shade_Wm2 min: 0.031 mean: 6.670 max: 32.315 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable ANIRin_sunlit_Wm2 min: 0.027 mean: 3.803 max: 36.241 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable ANIRin_shade_Wm2 min: 0.000 mean: 0.923 max: 9.945 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable NIRin_soil_Wm2 min: 15.630 mean: 72.355 max: 236.778 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable ANIR_soil_Wm2 min: 10.941 mean: 50.648 max: 165.744 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable ANIRout_sunlit_Wm2 min: 4.262 mean: 20.471 max: 69.538 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable ANIRout_Wm2 min: 0.008 mean: 1.236 max: 7.446 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable ANIR_sunlit_Wm2 min: 4.987 mean: 24.274 max: 85.698 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable ANIR_shade_Wm2 min: 0.008 mean: 2.159 max: 17.391 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable G_Wm2 min: 3.936 mean: 20.502 max: 63.881 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable ASW_sunlit_Wm2 min: 10.871 mean: 59.304 max: 215.273 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable ASW_shade_Wm2 min: 0.078 mean: 13.496 max: 64.320 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable ASW_soil_Wm2 min: 26.825 mean: 133.873 max: 433.019 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APAR_sunlit_Wm2 min: 5.455 mean: 33.666 max: 139.078 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APAR_sunlit_μmolm2s1 min: 24.875 mean: 153.515 max: 634.194 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APAR_shade_Wm2 min: 0.031 mean: 6.670 max: 32.315 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APAR_shade_μmolm2s1 min: 0.141 mean: 30.416 max: 147.357 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable fSun min: 0.182 mean: 0.244 max: 0.282 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APAR_sunlit_μmolm2s1 min: 24.875 mean: 153.515 max: 634.194 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable APAR_shade_μmolm2s1 min: 0.141 mean: 30.416 max: 147.357 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable ASW_sunlit_Wm2 min: 10.871 mean: 59.304 max: 215.273 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable ASW_shade_Wm2 min: 0.078 mean: 13.496 max: 64.320 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable ASW_soil_Wm2 min: 26.825 mean: 133.873 max: 433.019 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable G_Wm2 min: 3.936 mean: 20.502 max: 63.881 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable GPP_C3 min: 0.000 mean: 2.477 max: 22.146 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable LE_C3 min: 0.000 mean: 46.450 max: 920.941 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable LE_soil_C3 min: 0.000 mean: 29.884 max: 595.817 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable LE_canopy_C3 min: 0.000 mean: 16.565 max: 474.363 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable Rn_C3 min: 0.000 mean: 159.741 max: 1000.000 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable Rn_soil_C3 min: 0.000 mean: 82.918 max: 791.396 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable Rn_canopy_C3 min: 0.000 mean: 83.603 max: 1007.482 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable GPP_C4 min: 0.000 mean: 2.398 max: 37.840 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable LE_C4 min: 0.000 mean: 46.029 max: 969.405 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable LE_soil_C4 min: 0.000 mean: 29.884 max: 595.817 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable LE_canopy_C4 min: 0.000 mean: 16.144 max: 468.541 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable Rn_C4 min: 0.000 mean: 159.741 max: 1000.000 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable Rn_soil_C4 min: 0.000 mean: 82.918 max: 791.396 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable Rn_canopy_C4 min: 0.000 mean: 83.603 max: 1007.482 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] started daylight ET upscaling
# [2026-08-07 17:55:45 INFO] completed daylight ET upscaling (elapsed: 0.08 seconds)
# [2026-08-07 17:55:45 INFO] completed processing BESS-JPL in 0.27 seconds
# [2026-08-07 17:55:45 INFO] variable Rn_BESS_Wm2 min: 0.000 mean: 159.741 max: 1000.000 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable Rn_BESS_Wm2 min: 0.000 mean: 159.741 max: 1000.000 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable LE_BESS_Wm2 min: 0.000 mean: 46.417 max: 921.476 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] calculating solar day of year
# [2026-08-07 17:55:45 INFO] calculating solar hour of day
# [2026-08-07 17:55:45 INFO] calculating daylight hours and sunrise hour
# [2026-08-07 17:55:45 INFO] variable LE_BESS_Wm2 min: 0.000 mean: 46.417 max: 921.476 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable GPP_inst_umol_m2_s min: 0.000 mean: 2.471 max: 22.553 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] starting Verma net radiation processing
# [2026-08-07 17:55:45 INFO] variable SWout_Wm2 min: 1.953 mean: 88.450 max: 418.367 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable SWnet_Wm2 min: 50.240 mean: 174.606 max: 636.421 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable LWin_Wm2 min: 173.475 mean: 306.324 max: 518.258 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable LWout_Wm2 min: 241.578 mean: 516.009 max: 893.522 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable Rn_Wm2 min: 0.000 mean: 75.972 max: 803.032 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] Verma net radiation processing complete in 0.00 seconds
# [2026-08-07 17:55:45 INFO] running Surface Temperature Initiated Closure
# [2026-08-07 17:55:45 INFO] variable Ms min: 0.000 mean: 0.248 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] running STIC iteration 1 / 3
# [2026-08-07 17:55:45 INFO] using variable Priestley-Taylor alpha with mean: 0.933
# [2026-08-07 17:55:45 INFO] completed STIC iteration 1 / 3 with max LE change: 1713.033 (0.002171375002944842 seconds)
# [2026-08-07 17:55:45 INFO] variable SM_1 min: 0.000 mean: 0.261 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable G_1 min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable LE_1 min: 0.000 mean: 40.317 max: 542.023 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] running STIC iteration 2 / 3
# [2026-08-07 17:55:45 INFO] using variable Priestley-Taylor alpha with mean: 1.418
# [2026-08-07 17:55:45 INFO] completed STIC iteration 2 / 3 with max LE change: 54.495 (0.006441875011660159 seconds)
# [2026-08-07 17:55:45 INFO] variable SM_2 min: 0.000 mean: 0.264 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable G_2 min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable LE_2 min: 0.000 mean: 40.671 max: 542.023 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] running STIC iteration 3 / 3
# [2026-08-07 17:55:45 INFO] using variable Priestley-Taylor alpha with mean: 2.915
# [2026-08-07 17:55:45 INFO] completed STIC iteration 3 / 3 with max LE change: 184.912 (0.010380209016148001 seconds)
# [2026-08-07 17:55:45 INFO] variable SM_3 min: 0.000 mean: 0.264 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:55:45 INFO] variable G_3 min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] variable LE_3 min: 0.000 mean: 43.095 max: 674.432 nan: 8.59% (nan)
# [2026-08-07 17:55:45 INFO] started daily ET upscaling (STIC-JPL)
# [2026-08-07 17:55:46 INFO] completed daily ET upscaling (elapsed: 0.08 seconds)
# [2026-08-07 17:55:46 INFO] completed processing STIC-JPL in 0.20 seconds
# [2026-08-07 17:55:46 INFO] variable LE_STIC_Wm2 min: 0.000 mean: 43.095 max: 674.432 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable ET_daylight_STIC_kg min: 0.000 mean: 0.465 max: 6.924 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_canoy_STIC_Wm2 min: 0.000 mean: 9.123 max: 395.749 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable G_STIC_Wm2 min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_canopy_fraction_STIC min: 0.000 mean: 0.172 max: 1.000 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] running Priestley-Taylor JPL with Soil Moisture
# [2026-08-07 17:55:46 INFO] starting PT-JPL-SM model run
# [2026-08-07 17:55:46 INFO] using given optimum temperature (Topt_C)
# [2026-08-07 17:55:46 INFO] variable Topt_C (float64) with [10.09] unique values
# [2026-08-07 17:55:46 INFO] * 10.09: 6144
# [2026-08-07 17:55:46 INFO] variable fAPARmax (float64) with [0.4659] unique values
# [2026-08-07 17:55:46 INFO] * 0.4659: 6144
# [2026-08-07 17:55:46 INFO] using given air temperature (Ta_C)
# [2026-08-07 17:55:46 INFO] variable Ta_C min: -14.499 mean: 12.553 max: 39.604 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] using given relative humidity (RH)
# [2026-08-07 17:55:46 INFO] variable RH min: 0.274 mean: 0.628 max: 0.982 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] using given soil moisture (SM)
# [2026-08-07 17:55:46 INFO] variable soil_moisture (float64) with [0.19235913] unique values
# [2026-08-07 17:55:46 INFO] * 0.19235913: 6144
# [2026-08-07 17:55:46 INFO] using given field capacity
# [2026-08-07 17:55:46 INFO] variable field_capacity (float64) with [0.24] unique values
# [2026-08-07 17:55:46 INFO] * 0.24: 6144
# [2026-08-07 17:55:46 INFO] using given wilting point
# [2026-08-07 17:55:46 INFO] variable wilting_point (float64) with [0.11] unique values
# [2026-08-07 17:55:46 INFO] * 0.11: 6144
# [2026-08-07 17:55:46 INFO] using given canopy height
# [2026-08-07 17:55:46 INFO] variable canopy_height_meters min: 0.059 mean: 15.096 max: 30.133 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] using given net radiation (Rn_Wm2) for PT-JPL-SM processing
# [2026-08-07 17:55:46 INFO] variable Rn_Wm2 min: 0.000 mean: 75.972 max: 803.032 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] using given soil heat flux (G_Wm2)
# [2026-08-07 17:55:46 INFO] variable G min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable fwet min: 0.006 mean: 0.259 max: 0.931 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable fREW (float64) with [1.] unique values
# [2026-08-07 17:55:46 INFO] * 1.0: 6144
# [2026-08-07 17:55:46 INFO] variable Topt_C (float64) with [10.09] unique values
# [2026-08-07 17:55:46 INFO] * 10.09: 6144
# [2026-08-07 17:55:46 INFO] variable Topt_C min: 10.090 mean: 18.167 max: 39.604 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable epsilon min: 0.199 mean: 0.565 max: 0.853 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable Rn_soil_Wm2 min: 0.000 mean: 38.214 max: 589.714 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_soil_Wm2 min: 0.000 mean: 29.337 max: 599.242 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable Rn_canopy_Wm2 min: 0.000 mean: 38.612 max: 511.241 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable PET min: 0.000 mean: 62.503 max: 816.006 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable fTRM min: 0.001 mean: 0.619 max: 1.000 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 19.242 max: 342.070 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_interception_Wm2 min: 0.000 mean: 9.002 max: 400.929 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_Wm2 min: 0.000 mean: 57.581 max: 789.186 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] started daylight ET upscaling
# [2026-08-07 17:55:46 INFO] completed daylight ET upscaling (elapsed: 0.12 seconds)
# [2026-08-07 17:55:46 INFO] PT-JPL-SM model run complete (elapsed: 0.14 seconds)
# [2026-08-07 17:55:46 INFO] completed processing PT-JPL-SM in 0.14 seconds
# [2026-08-07 17:55:46 INFO] variable LE_PTJPLSM_Wm2 min: 0.000 mean: 57.581 max: 789.186 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable ET_daylight_PTJPLSM_kg min: 0.000 mean: 0.626 max: 8.102 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable G_PTJPLSM min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable EF_PTJPLSM min: 0.000 mean: 0.338 max: 1.073 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_canopy_PTJPLSM_Wm2 min: 0.000 mean: 19.242 max: 342.070 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_canopy_fraction_PTJPLSM min: 0.000 mean: 0.313 max: 0.958 nan: 57.01% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_soil_PTJPLSM_Wm2 min: 0.000 mean: 29.337 max: 599.242 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_soil_fraction_PTJPLSM min: 0.000 mean: 0.519 max: 0.999 nan: 57.01% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_interception_PTJPLSM_Wm2 min: 0.000 mean: 9.002 max: 400.929 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_interception_fraction_PTJPLSM min: 0.000 mean: 0.168 max: 0.999 nan: 57.01% (nan)
# [2026-08-07 17:55:46 INFO] variable PET_instantaneous_PTJPLSM_Wm2 min: 0.000 mean: 62.503 max: 816.006 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable ESI_PTJPLSM min: 0.161 mean: 0.878 max: 1.000 nan: 57.01% (nan)
# [2026-08-07 17:55:46 INFO] running Penman-Monteith JPL
# [2026-08-07 17:55:46 INFO] variable Ta_C min: -14.499 mean: 12.553 max: 39.604 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable Tmin_C (float64) with [32.65892] unique values
# [2026-08-07 17:55:46 INFO] * 32.65892: 6144
# [2026-08-07 17:55:46 INFO] variable IGBP (float32) with [12.] unique values
# [2026-08-07 17:55:46 INFO] * 12.0: 6144
# [2026-08-07 17:55:46 INFO] using given net radiation (Rn_Wm2) for PM-JPL processing
# [2026-08-07 17:55:46 INFO] variable Rn_Wm2 min: 0.000 mean: 75.972 max: 803.032 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable G_Wm2 min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] calculating PM-MOD meteorology
# [2026-08-07 17:55:46 INFO] variable specific_humidity min: 0.001 mean: 0.007 max: 0.037 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable rho_kgm3 min: 1.116 mean: 1.556 max: 2.011 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable Cp_Jkg min: 1006.003 mean: 1011.192 max: 1035.834 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable delta_Pa min: 16.422 mean: 129.776 max: 384.586 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable fwet min: 0.000 mean: 0.212 max: 0.931 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] calculating PM-MOD resistances
# [2026-08-07 17:55:46 INFO] variable gl_sh (float32) with [0.02] unique values
# [2026-08-07 17:55:46 INFO] * 0.02: 6144
# [2026-08-07 17:55:46 INFO] variable rhc min: 12.890 mean: 1290.860 max: 2000.000 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable rrc min: 165.480 mean: 304.482 max: 504.386 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable rhrc min: 12.289 mean: 193.172 max: 402.683 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable gl_e_wv (float32) with [0.02] unique values
# [2026-08-07 17:55:46 INFO] * 0.02: 6144
# [2026-08-07 17:55:46 INFO] variable rvc min: 12.890 mean: 1290.860 max: 2000.000 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable Ac min: 0.000 mean: 57.400 max: 630.128 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_interception_Wm2 min: 0.000 mean: 15.350 max: 444.584 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable rcorr min: 0.901 mean: 1.328 max: 1.824 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable CL (float32) with [0.007] unique values
# [2026-08-07 17:55:46 INFO] * 0.007: 6144
# [2026-08-07 17:55:46 INFO] variable Tmin_open (float32) with [12.02] unique values
# [2026-08-07 17:55:46 INFO] * 12.02: 6144
# [2026-08-07 17:55:46 INFO] variable Tmin_closed (float32) with [-8.] unique values
# [2026-08-07 17:55:46 INFO] * -8.0: 6144
# [2026-08-07 17:55:46 INFO] variable Tmin_C (float64) with [32.65892] unique values
# [2026-08-07 17:55:46 INFO] * 32.65892: 6144
# [2026-08-07 17:55:46 INFO] variable mTmin (float64) with [1.] unique values
# [2026-08-07 17:55:46 INFO] * 1.0: 6144
# [2026-08-07 17:55:46 INFO] variable VPD_open (float32) with [650.] unique values
# [2026-08-07 17:55:46 INFO] * 650.0: 6144
# [2026-08-07 17:55:46 INFO] variable VPD_closed (float32) with [4500.] unique values
# [2026-08-07 17:55:46 INFO] * 4500.0: 6144
# [2026-08-07 17:55:46 INFO] variable mVPD min: 0.000 mean: 0.895 max: 1.000 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable gs1 min: 0.000 mean: 0.008 max: 0.013 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable Gcu min: 0.000 mean: 0.000 max: 0.000 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable Cc min: 0.001 mean: 0.006 max: 0.035 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable rs min: 28.973 mean: 615.948 max: 2000.000 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable rh min: 28.973 mean: 615.948 max: 2000.000 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable rr min: 165.480 mean: 304.482 max: 504.386 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable ra min: 38.398 mean: 42.642 max: 45.491 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_canopy_Wm2 min: 0.000 mean: 56.909 max: 520.308 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable RBL_max (float32) with [50.] unique values
# [2026-08-07 17:55:46 INFO] * 50.0: 6144
# [2026-08-07 17:55:46 INFO] variable RBL_min (float32) with [20.] unique values
# [2026-08-07 17:55:46 INFO] * 20.0: 6144
# [2026-08-07 17:55:46 INFO] variable rtotc min: 20.000 mean: 46.838 max: 50.000 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable rtot min: 18.026 mean: 62.586 max: 91.191 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable rrs min: 165.480 mean: 304.482 max: 504.386 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable ras min: 16.256 mean: 51.815 max: 77.229 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable Asoil min: 0.000 mean: 17.314 max: 496.819 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable wet_soil_evaporation_Wm2 min: 0.000 mean: 4.664 max: 227.758 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable potential_soil_evaporation_Wm2 min: 0.000 mean: 38.791 max: 707.261 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable fSM min: 0.000 mean: 0.356 max: 0.998 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_soil_Wm2 min: 0.000 mean: 8.630 max: 312.475 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] variable LE_Wm2 min: 0.000 mean: 47.860 max: 540.463 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] started daylight ET upscaling (PMJPL)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# [2026-08-07 17:55:46 INFO] completed daylight ET upscaling (PMJPL)
# [2026-08-07 17:55:46 INFO] completed processing PM-JPL in 0.17 seconds
# [2026-08-07 17:55:46 INFO] variable LE_PMJPL_Wm2 min: 0.000 mean: 47.860 max: 540.463 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable ET_daylight_PMJPL_kg min: 0.000 mean: 0.523 max: 5.549 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable G_PMJPL_Wm2 min: -0.000 mean: 3.927 max: 103.297 nan: 8.59% (nan)
# [2026-08-07 17:55:46 INFO] variable ET_daylight_kg min: 0.000 mean: 0.484 max: 6.834 nan: 0.00% (nan)
# [2026-08-07 17:55:46 INFO] JET table processing complete (1.365 seconds)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:37: UserWarning: no explicit representation of timezones available for np.datetime64
#   return np.array(arr, dtype='datetime64[ns]')
# /opt/homebrew/Caskroom/miniforge/base/envs/JET3/lib/python3.13/site-packages/solar_apparent_time/solar_apparent_time.py:212: DeprecationWarning: The 'generic' unit for NumPy timedelta is deprecated, and will raise an error in the future. This includes implicit conversion of bare integers (e.g. `+ 1`).Please use a specific unit instead.
#   doy_UTC = ((times_b.astype('datetime64[D]') - year_start.astype('datetime64[D]')) + 1).astype(int)

# %% [markdown]
# ## Analyze and Visualize Sobol Indices
# We extract the target array, analyze the outputs via the Sobol library, and map the First-Order and Total-Order variance percentages into a comparison chart.

# %%
# Set Seaborn style for the bar chart
sns.set_theme(style="whitegrid")
colors = sns.color_palette("deep")

target_output = "ET_daylight_kg"
Y = processed_samples[target_output].values

# Calculate Sobol indices
Si = sobol.analyze(problem, Y, calc_second_order=True)

# Visualizing First-Order and Total-Order Indices
# Updated figsize to (10, 10) for a square aspect ratio
fig, ax = plt.subplots(figsize=(10, 10)) 
x = np.arange(len(input_variables))
width = 0.35

ax.bar(x - width/2, Si['S1'], width, label='S1 (First-order: Direct Variance)', color=colors[0], edgecolor="white", linewidth=1)
ax.bar(x + width/2, Si['ST'], width, label='ST (Total-order: Includes Interactions)', color=colors[1], edgecolor="white", linewidth=1)

ax.set_ylabel('Sobol Index', fontsize=12, weight='bold')
ax.set_title(f'Sobol Sensitivity Indices for {target_output}', fontsize=15, weight='bold', pad=15)
ax.set_xticks(x)
ax.set_xticklabels(input_variables, rotation=45, ha='right', fontsize=11)
ax.legend(frameon=True, facecolor='white', edgecolor='lightgray')

# Remove top and right borders for a cleaner look
sns.despine(left=True)
ax.grid(axis='y', linestyle='-', alpha=0.5)

plt.tight_layout()
plt.show()
